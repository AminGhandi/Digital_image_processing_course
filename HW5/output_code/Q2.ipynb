# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt


images = cv2.imread('flag.png' ,cv2.IMREAD_GRAYSCALE)
binary = cv2.adaptiveThreshold(images, 1, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 3)


fig = plt.figure(figsize=(12,12))
fig.add_subplot(2,2,1)
plt.title('orginal')
plt.imshow(images, cmap = 'gray')

fig.add_subplot(2,2,2)
plt.title('binary')
plt.imshow(binary, cmap = 'gray')
plt.show()

# %%
def dilation(image_path, kernel_size):
    # Read the image for dilation
    img2 = image_path
    
    # Acquire size of the image
    p, q = img2.shape
    

    # Define new image to store the pixels of dilated image
    imgDilate = np.zeros((p, q), dtype=np.uint8)
    
    # Define the structuring element
    SED = np.ones((kernel_size, kernel_size), dtype=np.uint8)
    constant1 = (kernel_size - 1) // 2
    
    # Dilation operation without using inbuilt CV2 function
    for i in range(constant1, p - constant1):
        for j in range(constant1, q - constant1):
            temp = img2[i - constant1 : i + constant1 + 1, j - constant1 : j + constant1 + 1]
            product = temp * SED
            imgDilate[i, j] = np.min(product)
    
    fig = plt.figure(figsize=(12,12))
    fig.add_subplot(2,2,1)
    plt.title('orginal')
    plt.imshow(img2, cmap = 'gray')

    fig.add_subplot(2,2,2)
    plt.title('dilation')
    plt.imshow(imgDilate, cmap = 'gray')
    plt.show()

# %%
dilation(binary, 5)

# %%
def erosion(image_path, kernel_size):
    # Read the image for erosion
    img1 = image_path
    
    # Acquire size of the image
    m, n = img1.shape 
    

    
    # Define the structuring element
    SE = np.ones((kernel_size, kernel_size), dtype=np.uint8)
    constant = (kernel_size - 1) // 2
    
    # Define new image
    imgErode = np.zeros((m, n), dtype=np.uint8)
    
    # Erosion without using inbuilt cv2 function for morphology
    for i in range(constant, m - constant):
        for j in range(constant, n - constant):
            temp = img1[i - constant : i + constant + 1, j - constant : j + constant + 1]
            product = temp * SE
            imgErode[i, j] = np.max(product)
    

    fig = plt.figure(figsize=(12,12))
    fig.add_subplot(2,2,1)
    plt.title('orginal')
    plt.imshow(img1, cmap = 'gray')

    fig.add_subplot(2,2,2)
    plt.title('erosion')
    plt.imshow(imgErode, cmap = 'gray')
    plt.show()

# %%
erosion(binary, 5)
